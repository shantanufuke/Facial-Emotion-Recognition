# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow.keras as keras

import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

import datetime
import torch
import os
from PIL import Image
import cv2

# %%
# Define transformations for the input data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load the training and test datasets
train_generator = train_datagen.flow_from_directory(
    'FER2013/train',
    target_size=(48, 48),
    batch_size=128,
    color_mode='grayscale',
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    'FER2013/test',
    target_size=(48, 48),
    batch_size=128,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 28386 images belonging to 8 classes.
# Found 7099 images belonging to 8 classes.

# %%
@tf.keras.utils.register_keras_serializable()
class EmotionCNN(Model):
    def __init__(self, trainable=True, dtype=tf.float32, **kwargs):
        super(EmotionCNN, self).__init__(trainable=trainable, dtype=dtype, **kwargs)
        self.conv1 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=(48, 48, 1))
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(64, kernel_size=(3, 3), padding='same')
        self.bn2 = layers.BatchNormalization()
        self.conv3 = layers.Conv2D(128, kernel_size=(3, 3), padding='same')
        self.bn3 = layers.BatchNormalization()
        self.pool = layers.MaxPooling2D(pool_size=(2, 2))
        self.dropout = layers.Dropout(0.5)
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(256)
        self.fc2 = layers.Dense(8)  # 8 classes for emotion

    def call(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = tf.nn.relu(x)
        x = self.pool(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = tf.nn.relu(x)
        x = self.pool(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = tf.nn.relu(x)
        x = self.pool(x)

        x = self.flatten(x)
        x = self.fc1(x)
        x = tf.nn.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return tf.nn.softmax(x)

    def get_config(self):
        config = super(EmotionCNN, self).get_config()
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %%
model = EmotionCNN()
# Out:
# /Users/shantanufuke/miniconda3/envs/pytorch/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-05-27 22:18:34.714768: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-05-27 22:18:34.714796: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-05-27 22:18:34.714801: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-05-27 22:18:34.714821: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-05-27 22:18:34.714835: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Call the model on a sample input to build it
sample_input = tf.random.normal([1, 48, 48, 1])
_ = model(sample_input)

# %%
model.summary()
# Out:
# Model: "emotion_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ ?                      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ ?                      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ ?                      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ ?                      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,275,528 (4.87 MB)
#  Trainable params: 1,275,080 (4.86 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model = EmotionCNN()

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Define ModelCheckpoint and EarlyStopping callbacks
model_checkpoint_callback = ModelCheckpoint(filepath='emotion_cnn_checkpoint.keras',
                                            monitor='val_accuracy', save_best_only=True, mode ='max', verbose = 1)
early_stopping_callback = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, mode = 'max')

model.fit(
        train_generator,
        epochs=50,
        validation_data=validation_generator,
        callbacks = [model_checkpoint_callback, early_stopping_callback]
    )
# Out:
# Epoch 1/50
# 2024-05-26 12:44:51.964968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /Users/shantanufuke/miniconda3/envs/pytorch/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3781 - loss: 1.5869
# Epoch 1: val_accuracy improved from -inf to 0.55966, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 30s 126ms/step - accuracy: 0.3783 - loss: 1.5864 - val_accuracy: 0.5597 - val_loss: 1.2911
# Epoch 2/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5604 - loss: 1.2590
# Epoch 2: val_accuracy improved from 0.55966 to 0.61051, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.5605 - loss: 1.2588 - val_accuracy: 0.6105 - val_loss: 1.0905
# Epoch 3/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6101 - loss: 1.1003
# Epoch 3: val_accuracy improved from 0.61051 to 0.64896, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6102 - loss: 1.1002 - val_accuracy: 0.6490 - val_loss: 0.9793
# Epoch 4/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6553 - loss: 0.9777
# Epoch 4: val_accuracy improved from 0.64896 to 0.67855, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.6553 - loss: 0.9776 - val_accuracy: 0.6785 - val_loss: 0.9107
# Epoch 5/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6741 - loss: 0.9042
# Epoch 5: val_accuracy improved from 0.67855 to 0.68897, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.6742 - loss: 0.9042 - val_accuracy: 0.6890 - val_loss: 0.8859
# Epoch 6/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6889 - loss: 0.8646
# Epoch 6: val_accuracy improved from 0.68897 to 0.69883, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.6890 - loss: 0.8646 - val_accuracy: 0.6988 - val_loss: 0.8491
# Epoch 7/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7057 - loss: 0.8203
# Epoch 7: val_accuracy improved from 0.69883 to 0.70447, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.7057 - loss: 0.8202 - val_accuracy: 0.7045 - val_loss: 0.8355
# Epoch 8/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7244 - loss: 0.7767
# Epoch 8: val_accuracy improved from 0.70447 to 0.71334, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.7244 - loss: 0.7767 - val_accuracy: 0.7133 - val_loss: 0.7977
# Epoch 9/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7366 - loss: 0.7426
# Epoch 9: val_accuracy improved from 0.71334 to 0.71841, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.7366 - loss: 0.7426 - val_accuracy: 0.7184 - val_loss: 0.8148
# Epoch 10/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.7372 - loss: 0.7360
# Epoch 10: val_accuracy improved from 0.71841 to 0.73546, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.7372 - loss: 0.7359 - val_accuracy: 0.7355 - val_loss: 0.7552
# Epoch 11/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7458 - loss: 0.7022
# Epoch 11: val_accuracy did not improve from 0.73546
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.7458 - loss: 0.7021 - val_accuracy: 0.7340 - val_loss: 0.7585
# Epoch 12/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.7579 - loss: 0.6739
# Epoch 12: val_accuracy did not improve from 0.73546
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.7579 - loss: 0.6739 - val_accuracy: 0.7312 - val_loss: 0.7652
# Epoch 13/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.7643 - loss: 0.6584
# Epoch 13: val_accuracy improved from 0.73546 to 0.74687, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 32s 141ms/step - accuracy: 0.7643 - loss: 0.6583 - val_accuracy: 0.7469 - val_loss: 0.7161
# Epoch 14/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7753 - loss: 0.6152
# Epoch 14: val_accuracy did not improve from 0.74687
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 27s 119ms/step - accuracy: 0.7753 - loss: 0.6152 - val_accuracy: 0.7364 - val_loss: 0.7539
# Epoch 15/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7782 - loss: 0.6150
# Epoch 15: val_accuracy improved from 0.74687 to 0.74940, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.7782 - loss: 0.6150 - val_accuracy: 0.7494 - val_loss: 0.7201
# Epoch 16/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.7830 - loss: 0.5854
# Epoch 16: val_accuracy did not improve from 0.74940
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - accuracy: 0.7830 - loss: 0.5854 - val_accuracy: 0.7436 - val_loss: 0.7378
# Epoch 17/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7918 - loss: 0.5744
# Epoch 17: val_accuracy improved from 0.74940 to 0.75377, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.7918 - loss: 0.5745 - val_accuracy: 0.7538 - val_loss: 0.7280
# Epoch 18/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7975 - loss: 0.5527
# Epoch 18: val_accuracy did not improve from 0.75377
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 113ms/step - accuracy: 0.7975 - loss: 0.5527 - val_accuracy: 0.7483 - val_loss: 0.7324
# Epoch 19/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8087 - loss: 0.5289
# Epoch 19: val_accuracy improved from 0.75377 to 0.76095, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.8087 - loss: 0.5289 - val_accuracy: 0.7610 - val_loss: 0.7221
# Epoch 20/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8146 - loss: 0.5159
# Epoch 20: val_accuracy did not improve from 0.76095
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - accuracy: 0.8146 - loss: 0.5159 - val_accuracy: 0.7491 - val_loss: 0.7341
# Epoch 21/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8202 - loss: 0.5027
# Epoch 21: val_accuracy improved from 0.76095 to 0.76194, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - accuracy: 0.8201 - loss: 0.5027 - val_accuracy: 0.7619 - val_loss: 0.7260
# Epoch 22/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8174 - loss: 0.5063
# Epoch 22: val_accuracy did not improve from 0.76194
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 113ms/step - accuracy: 0.8174 - loss: 0.5063 - val_accuracy: 0.7542 - val_loss: 0.7286
# Epoch 23/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8286 - loss: 0.4852
# Epoch 23: val_accuracy did not improve from 0.76194
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8286 - loss: 0.4852 - val_accuracy: 0.7574 - val_loss: 0.7468
# Epoch 24/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8320 - loss: 0.4690
# Epoch 24: val_accuracy improved from 0.76194 to 0.76701, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8320 - loss: 0.4690 - val_accuracy: 0.7670 - val_loss: 0.7424
# Epoch 25/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8363 - loss: 0.4482
# Epoch 25: val_accuracy did not improve from 0.76701
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 113ms/step - accuracy: 0.8362 - loss: 0.4483 - val_accuracy: 0.7600 - val_loss: 0.7413
# Epoch 26/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8400 - loss: 0.4377
# Epoch 26: val_accuracy did not improve from 0.76701
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 109ms/step - accuracy: 0.8400 - loss: 0.4377 - val_accuracy: 0.7483 - val_loss: 0.7646
# Epoch 27/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8418 - loss: 0.4370
# Epoch 27: val_accuracy did not improve from 0.76701
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.8418 - loss: 0.4370 - val_accuracy: 0.7614 - val_loss: 0.7827
# Epoch 28/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8506 - loss: 0.4186
# Epoch 28: val_accuracy did not improve from 0.76701
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8506 - loss: 0.4187 - val_accuracy: 0.7556 - val_loss: 0.7818
# Epoch 29/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8536 - loss: 0.4038
# Epoch 29: val_accuracy did not improve from 0.76701
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8536 - loss: 0.4039 - val_accuracy: 0.7653 - val_loss: 0.7580
# Epoch 30/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8531 - loss: 0.4062
# Epoch 30: val_accuracy did not improve from 0.76701
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.8531 - loss: 0.4062 - val_accuracy: 0.7646 - val_loss: 0.7871
# Epoch 31/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8645 - loss: 0.3789
# Epoch 31: val_accuracy improved from 0.76701 to 0.76856, saving model to emotion_cnn_checkpoint.keras
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8645 - loss: 0.3789 - val_accuracy: 0.7686 - val_loss: 0.7876
# Epoch 32/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8652 - loss: 0.3629
# Epoch 32: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 114ms/step - accuracy: 0.8652 - loss: 0.3630 - val_accuracy: 0.7617 - val_loss: 0.8212
# Epoch 33/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8683 - loss: 0.3623
# Epoch 33: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.8682 - loss: 0.3624 - val_accuracy: 0.7652 - val_loss: 0.7943
# Epoch 34/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8745 - loss: 0.3458
# Epoch 34: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.8745 - loss: 0.3459 - val_accuracy: 0.7681 - val_loss: 0.8164
# Epoch 35/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8791 - loss: 0.3425
# Epoch 35: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.8790 - loss: 0.3425 - val_accuracy: 0.7652 - val_loss: 0.8412
# Epoch 36/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8751 - loss: 0.3419
# Epoch 36: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8751 - loss: 0.3420 - val_accuracy: 0.7670 - val_loss: 0.8654
# Epoch 37/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8806 - loss: 0.3326
# Epoch 37: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.8806 - loss: 0.3326 - val_accuracy: 0.7615 - val_loss: 0.8402
# Epoch 38/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8835 - loss: 0.3242
# Epoch 38: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.8835 - loss: 0.3242 - val_accuracy: 0.7621 - val_loss: 0.8613
# Epoch 39/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.8906 - loss: 0.3017
# Epoch 39: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 26s 117ms/step - accuracy: 0.8906 - loss: 0.3018 - val_accuracy: 0.7614 - val_loss: 0.8635
# Epoch 40/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8891 - loss: 0.3037
# Epoch 40: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 113ms/step - accuracy: 0.8890 - loss: 0.3038 - val_accuracy: 0.7555 - val_loss: 0.9160
# Epoch 41/50
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8870 - loss: 0.3058
# Epoch 41: val_accuracy did not improve from 0.76856
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.8870 - loss: 0.3058 - val_accuracy: 0.7517 - val_loss: 0.8579

# %%
def run_emotion_recognition(model_path='emotion_cnn_checkpoint.keras', emotion_labels=None):
    # Load the trained emotion recognition model
    model = load_model(model_path)

    if emotion_labels is None:
        # Define emotion labels if not provided
        emotion_labels = ['Angry', 'Contempt', 'Disgust', 'Fear','Happy','Neutral','Sad','Suprice']

    # Load the face detection cascade classifier
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

    # Start video capture
    cap = cv2.VideoCapture(0)

    while True:
        ret, frame = cap.read()

        if not ret:
            break

        # Convert frame to grayscale for face detection
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Detect faces in the frame
        faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        # Process each detected face
        for (x, y, w, h) in faces:
            # Draw bounding box around the face
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

            # Crop the face region for emotion recognition
            face_roi = gray_frame[y:y+h, x:x+w]
            resized_face = cv2.resize(face_roi, (48, 48))
            normalized_face = resized_face / 255.0
            input_face = np.expand_dims(normalized_face, axis=-1)
            input_face = np.expand_dims(input_face, axis=0)

            # Predict emotion
            prediction = model.predict(input_face)
            predicted_class = np.argmax(prediction)
            emotion = emotion_labels[predicted_class]

            # Overlay emotion label on frame
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.putText(frame, emotion, (x, y - 10), font, 1, (0, 255, 0), 2, cv2.LINE_AA)

        # Display the frame
        cv2.imshow('Emotion Recognition', frame)

        # Exit on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the video capture
    cap.release()
    cv2.destroyAllWindows()

# %%
run_emotion_recognition()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 2024-05-27 22:18:42.611184: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
